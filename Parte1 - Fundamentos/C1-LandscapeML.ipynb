# %% [markdown]
# # C1. El Paisaje del Aprendizaje de Máquinas

# %% [markdown]
# * Definición del ML: es la ciencia y el arte de programar computadoras de manera que puedan aprender de los datos.
# * Según Arthur Samuel: *Es el campo de estudio que le da a la computadoras la habilidades de aprender sin ser explícitamente programas.*
# * Según Tom Mitchell: *Se dice que un programa aprende de la experiencia E con respecto a alguna tarea T y una medida de rendimiento P, si su rendimiento en T, medido por P, mejora con la experiencia E.*
#
# Un ejemplo es un detector de spam: el cual con base en la experiencia (en este caso, el etiquetado de correos spam por los usuarios), aprende a detectar y filtrar de manera más eficiente el correo no deseado en la bandeja de los usuarios. En cambio, solo copiar y descargar información de algún sitio no hace a la máquina mejor en alguna tarea específica.
#
# Un enfoque clásico en el *hard-coding* de las reglas para filtrar correos resultaría en un sistema complejo y de difícil mantenimiento, mientras que un modelo de ML que sea capaz de reconocer eficientemente patrones (predictores) que puedan etiquetar a un correo como spam resultaría en una solución de mejor rendimiento.
#
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
#
# Si el sistema fuese hard-codeado, ante la aparición de nuevos correos spam con patrones diferentes habría que generar nuevas reglas, mientras que con un modelo de ML por medio del etiquetado en sus datos de entrenamiento el modelo aprendería a identificar un nuevo patrón que pueda estar asociado a Spam, y se actualizaría para reconocerlo de forma consecuente. Es decir, *se adapta a los cambios*.
#
# ![image-2.png](attachment:image-2.png)
#
# Otros ejemplos de aplicación son problemas demasiado complejos para enfoques tradicionales o que no cuentan con un algoritmo específico de solución:
#
# * Reconocimiento de voz.
# * Aprendizaje y obtención de conocimiento a partir de los patrones reconocidos por el modelo: **Minería de Datos**
#
# Por ejemplo, analizando el filtrador de Spam las personas encargadas de diseñar el sistema pueden aprender qué palabras considera el modelo que están asociadas al Spam con el fin de ganar mayor conocimiento del problema que están abordando, y de ese modo, tomar decisiones sobre su desarrollo futuro con el fin de continuar operando de forma adecuada.
#
# ![image-4.png](attachment:image-4.png)
